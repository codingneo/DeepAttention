# %%
# -*- coding: utf-8 -*-
'''An implementation of sequence to sequence learning for performing addition
Input: "535+61"
Output: "596"
Padding is handled by using a repeated sentinel character (space)
Input may optionally be inverted, shown to increase performance in many tasks in:
"Learning to Execute"
http://arxiv.org/abs/1410.4615
and
"Sequence to Sequence Learning with Neural Networks"
http://papers.nips.cc/paper/5346-sequence-to-sequence-learning-with-neural-networks.pdf
Theoretically it introduces shorter term dependencies between source and target.
Two digits inverted:
+ One layer LSTM (128 HN), 5k training examples = 99% train/test accuracy in 55 epochs
Three digits inverted:
+ One layer LSTM (128 HN), 50k training examples = 99% train/test accuracy in 100 epochs
Four digits inverted:
+ One layer LSTM (128 HN), 400k training examples = 99% train/test accuracy in 20 epochs
Five digits inverted:
+ One layer LSTM (128 HN), 550k training examples = 99% train/test accuracy in 30 epochs
'''

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.engine.training import slice_X
from keras.layers import Activation, TimeDistributed, Dense, RepeatVector, recurrent
import numpy as np
from six.moves import range
# Out:
# Using Theano backend.

# %%
class CharacterTable(object):
    '''
    Given a set of characters:
    + Encode them to a one hot integer representation
    + Decode the one hot integer representation to their character output
    + Decode a vector of probabilities to their character output
    '''
    def __init__(self, chars, maxlen):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
        self.maxlen = maxlen

    def encode(self, C, maxlen=None):
        maxlen = maxlen if maxlen else self.maxlen
        X = np.zeros((maxlen, len(self.chars)))
        for i, c in enumerate(C):
            X[i, self.char_indices[c]] = 1
        return X

    def decode(self, X, calc_argmax=True):
        if calc_argmax:
            X = X.argmax(axis=-1)
        return ''.join(self.indices_char[x] for x in X)

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
# Parameters for the model and dataset
TRAINING_SIZE = 50000
DIGITS = 2
OPS = 2
INVERT = True
# Try replacing GRU, or SimpleRNN
RNN = recurrent.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1
MAXLEN = OPS * DIGITS + OPS - 1

# %%
chars = '0123456789+ '
ctable = CharacterTable(chars, MAXLEN)

# %%
questions = []
expected = []
seen = set()
print('Generating data...')
while len(questions) < TRAINING_SIZE:
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    
    ops = []
    for i in range(OPS):
        ops.append(f())
    # Skip any addition questions we've already seen
    # Also skip any such that X+Y == Y+X (hence the sorting)
    ops.sort()
    key = tuple(ops)
    if key in seen:
        continue
    seen.add(key)
    # Pad the data with spaces such that it is always MAXLEN
    q = '+'.join([str(op) for op in ops])
    query = q + ' ' * (MAXLEN - len(q))
    ans = str(sum(ops))
    # Answers can be of maximum size DIGITS + 1
    ans += ' ' * (DIGITS + 1 - len(ans))
    if INVERT:
        query = query[::-1]
    questions.append(query)
    expected.append(ans)
print('Total addition questions:', len(questions))
# Out:
# Generating data...

# %%
print('Vectorization...')
X = np.zeros((len(questions), MAXLEN, len(chars)), dtype=np.bool)
y = np.zeros((len(questions), DIGITS + 1, len(chars)), dtype=np.bool)
for i, sentence in enumerate(questions):
    X[i] = ctable.encode(sentence, maxlen=MAXLEN)
for i, sentence in enumerate(expected):
    y[i] = ctable.encode(sentence, maxlen=DIGITS + 1)

# Shuffle (X, y) in unison as the later parts of X will almost all be larger digits
indices = np.arange(len(y))
np.random.shuffle(indices)
X = X[indices]
y = y[indices]

# Explicitly set apart 10% for validation data that we never train over
split_at = len(X) - len(X) / 10
(X_train, X_val) = (slice_X(X, 0, split_at), slice_X(X, split_at))
(y_train, y_val) = (y[:split_at], y[split_at:])

print(X_train.shape)
print(y_train.shape)
# Out:
# Vectorization...
# (450, 5, 12)
# (450, 3, 12)

# %%
print('Build model...')
model = Sequential()
# "Encode" the input sequence using an RNN, producing an output of HIDDEN_SIZE
# note: in a situation where your input sequences have a variable length,
# use input_shape=(None, nb_feature).
model.add(RNN(HIDDEN_SIZE, input_shape=(MAXLEN, len(chars))))
# For the decoder's input, we repeat the encoded input for each time step
model.add(RepeatVector(DIGITS + 1))
# The decoder RNN could be multiple layers stacked or a single layer
for _ in range(LAYERS):
    model.add(RNN(HIDDEN_SIZE, return_sequences=True))

# For each of step of the output sequence, decide which character should be chosen
model.add(TimeDistributed(Dense(len(chars))))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Build model...

# %%
# Train the model each generation and show predictions against the validation dataset
for iteration in range(1, 200):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X_train, y_train, batch_size=BATCH_SIZE, nb_epoch=1,
              validation_data=(X_val, y_val))
    ###
    # Select 10 samples from the validation set at random so we can visualize errors
    for i in range(10):
        ind = np.random.randint(0, len(X_val))
        rowX, rowy = X_val[np.array([ind])], y_val[np.array([ind])]
        preds = model.predict_classes(rowX, verbose=0)
        q = ctable.decode(rowX[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        print('Q', q[::-1] if INVERT else q)
        print('T', correct)
        print(colors.ok + '☑' + colors.close if correct == guess else colors.fail + '☒' + colors.close, guess)
        print('---')
# Out:
# --------------------------------------------------
# Iteration 1
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 2.4684 - acc: 0.1859 - val_loss: 2.4236 - val_acc: 0.3000
# Q 9+66
# T 75
# ☒
# ---
# Q 32+62
# T 94
# ☒
# ---
# Q 40+54
# T 94
# ☒ 1
# ---
# Q 87+97
# T 184
# ☒
# ---
# Q 7+73
# T 80
# ☒
# ---
# Q 87+97
# T 184
# ☒
# ---
# Q 9+71
# T 80
# ☒
# ---
# Q 4+14
# T 18
# ☒
# ---
# Q 8+73
# T 81
# ☒
# ---
# Q 7+35
# T 42
# ☒
# ---
#
# --------------------------------------------------
# Iteration 2
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 2.3983 - acc: 0.2867 - val_loss: 2.3379 - val_acc: 0.2933
# Q 48+73
# T 121
# ☒
# ---
# Q 7+35
# T 42
# ☒
# ---
# Q 1+24
# T 25
# ☒
# ---
# Q 9+63
# T 72
# ☒
# ---
# Q 9+66
# T 75
# ☒
# ---
# Q 9+71
# T 80
# ☒
# ---
# Q 9+63
# T 72
# ☒
# ---
# Q 9+63
# T 72
# ☒
# ---
# Q 4+14
# T 18
# ☒
# ---
# Q 0+43
# T 43
# ☒
# ---
#
# --------------------------------------------------
# Iteration 3
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 2.2959 - acc: 0.2852 - val_loss: 2.1969 - val_acc: 0.2933
# Q 3+4
# T 7
# ☒
# ---
# Q 1+72
# T 73
# ☒
# ---
# Q 7+73
# T 80
# ☒
# ---
# Q 9+63
# T 72
# ☒
# ---
# Q 32+90
# T 122
# ☒
# ---
# Q 40+54
# T 94
# ☒
# ---
# Q 3+35
# T 38
# ☒
# ---
# Q 6+99
# T 105
# ☒
# ---
# Q 4+99
# T 103
# ☒
# ---
# Q 11+61
# T 72
# ☒
# ---
#
# --------------------------------------------------
# Iteration 4
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 2.1414 - acc: 0.2852 - val_loss: 2.0582 - val_acc: 0.2933
# Q 40+54
# T 94
# ☒
# ---
# Q 0+9
# T 9
# ☒
# ---
# Q 3+4
# T 7
# ☒
# ---
# Q 9+63
# T 72
# ☒
# ---
# Q 1+24
# T 25
# ☒
# ---
# Q 68+82
# T 150
# ☒
# ---
# Q 0+43
# T 43
# ☒
# ---
# Q 5+66
# T 71
# ☒
# ---
# Q 6+99
# T 105
# ☒
# ---
# Q 7+59
# T 66
# ☒
# ---
#
# --------------------------------------------------
# Iteration 5
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 2.0645 - acc: 0.2852 - val_loss: 2.0848 - val_acc: 0.2933
# Q 38+71
# T 109
# ☒
# ---
# Q 3+4
# T 7
# ☒
# ---
# Q 1+38
# T 39
# ☒
# ---
# Q 13+73
# T 86
# ☒
# ---
# Q 4+99
# T 103
# ☒
# ---
# Q 7+73
# T 80
# ☒
# ---
# Q 3+25
# T 28
# ☒
# ---
# Q 40+54
# T 94
# ☒
# ---
# Q 5+76
# T 81
# ☒
# ---
# Q 5+76
# T 81
# ☒
# ---
#
# --------------------------------------------------
# Iteration 6
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 2.0553 - acc: 0.2852 - val_loss: 2.0115 - val_acc: 0.2933
# Q 32+90
# T 122
# ☒
# ---
# Q 5+80
# T 85
# ☒
# ---
# Q 3+13
# T 16
# ☒
# ---
# Q 44+99
# T 143
# ☒
# ---
# Q 22+44
# T 66
# ☒
# ---
# Q 9+66
# T 75
# ☒
# ---
# Q 4+99
# T 103
# ☒
# ---
# Q 13+73
# T 86
# ☒
# ---
# Q 68+82
# T 150
# ☒
# ---
# Q 87+97
# T 184
# ☒
# ---
#
# --------------------------------------------------
# Iteration 7
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.9959 - acc: 0.2896 - val_loss: 1.9993 - val_acc: 0.3133
# Q 14+16
# T 30
# ☒
# ---
# Q 5+66
# T 71
# ☒
# ---
# Q 4+14
# T 18
# ☒
# ---
# Q 1+24
# T 25
# ☒
# ---
# Q 5+25
# T 30
# ☒
# ---
# Q 3+77
# T 80
# ☒
# ---
# Q 3+3
# T 6
# ☒
# ---
# Q 11+61
# T 72
# ☒
# ---
# Q 36+54
# T 90
# ☒
# ---
# Q 86+98
# T 184
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 8
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.9866 - acc: 0.3237 - val_loss: 1.9719 - val_acc: 0.3467
# Q 0+43
# T 43
# ☒
# ---
# Q 0+43
# T 43
# ☒
# ---
# Q 3+3
# T 6
# ☒
# ---
# Q 1+72
# T 73
# ☒
# ---
# Q 8+73
# T 81
# ☒
# ---
# Q 3+35
# T 38
# ☒
# ---
# Q 36+54
# T 90
# ☒
# ---
# Q 7+91
# T 98
# ☒
# ---
# Q 8+73
# T 81
# ☒
# ---
# Q 5+76
# T 81
# ☒
# ---
#
# --------------------------------------------------
# Iteration 9
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.9499 - acc: 0.3430 - val_loss: 1.9291 - val_acc: 0.3467
# Q 1+72
# T 73
# ☒
# ---
# Q 4+14
# T 18
# ☒
# ---
# Q 9+71
# T 80
# ☒
# ---
# Q 2+56
# T 58
# ☒
# ---
# Q 7+35
# T 42
# ☒
# ---
# Q 5+5
# T 10
# ☒
# ---
# Q 9+63
# T 72
# ☒
# ---
# Q 8+43
# T 51
# ☒
# ---
# Q 5+80
# T 85
# ☒ 1
# ---
# Q 48+73
# T 121
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 10
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.9217 - acc: 0.3481 - val_loss: 1.9082 - val_acc: 0.3533
# Q 14+16
# T 30
# ☒ 1
# ---
# Q 0+76
# T 76
# ☒ 1
# ---
# Q 9+66
# T 75
# ☒ 1
# ---
# Q 3+13
# T 16
# ☒
# ---
# Q 13+73
# T 86
# ☒
# ---
# Q 7+35
# T 42
# ☒
# ---
# Q 44+99
# T 143
# ☒ 11
# ---
# Q 14+16
# T 30
# ☒ 1
# ---
# Q 7+35
# T 42
# ☒
# ---
# Q 4+14
# T 18
# ☒
# ---
#
# --------------------------------------------------
# Iteration 11
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.8948 - acc: 0.3674 - val_loss: 1.8764 - val_acc: 0.3733
# Q 5+76
# T 81
# ☒ 1
# ---
# Q 3+4
# T 7
# ☒ 1
# ---
# Q 11+61
# T 72
# ☒ 1
# ---
# Q 1+24
# T 25
# ☒ 1
# ---
# Q 5+25
# T 30
# ☒ 1
# ---
# Q 0+43
# T 43
# ☒ 1
# ---
# Q 4+99
# T 103
# ☒ 11
# ---
# Q 6+36
# T 42
# ☒ 1
# ---
# Q 5+22
# T 27
# ☒ 1
# ---
# Q 8+73
# T 81
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 12
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.8632 - acc: 0.3911 - val_loss: 1.8562 - val_acc: 0.3733
# Q 1+24
# T 25
# ☒ 1
# ---
# Q 3+35
# T 38
# ☒ 1
# ---
# Q 3+35
# T 38
# ☒ 1
# ---
# Q 4+14
# T 18
# ☒ 1
# ---
# Q 7+35
# T 42
# ☒ 1
# ---
# Q 13+73
# T 86
# ☒ 1
# ---
# Q 9+66
# T 75
# ☒ 1
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 44+99
# T 143
# ☒ 111
# ---
# Q 3+77
# T 80
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 13
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.8345 - acc: 0.3956 - val_loss: 1.8175 - val_acc: 0.3733
# Q 38+71
# T 109
# ☒ 11
# ---
# Q 38+71
# T 109
# ☒ 11
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 1+38
# T 39
# ☒ 1
# ---
# Q 3+25
# T 28
# ☒ 1
# ---
# Q 11+61
# T 72
# ☒ 1
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 5+66
# T 71
# ☒ 1
# ---
# Q 8+73
# T 81
# ☒ 1
# ---
# Q 1+72
# T 73
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 14
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.8020 - acc: 0.3948 - val_loss: 1.7847 - val_acc: 0.3867
# Q 8+85
# T 93
# ☒ 11
# ---
# Q 2+56
# T 58
# ☒ 1
# ---
# Q 1+38
# T 39
# ☒ 1
# ---
# Q 5+25
# T 30
# ☒ 1
# ---
# Q 13+73
# T 86
# ☒ 1
# ---
# Q 8+85
# T 93
# ☒ 11
# ---
# Q 9+63
# T 72
# ☒ 1
# ---
# Q 9+63
# T 72
# ☒ 1
# ---
# Q 22+44
# T 66
# ☒ 1
# ---
# Q 3+4
# T 7
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 15
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.7659 - acc: 0.4044 - val_loss: 1.7612 - val_acc: 0.4067
# Q 3+64
# T 67
# ☒ 1
# ---
# Q 0+43
# T 43
# ☒ 1
# ---
# Q 44+99
# T 143
# ☒ 111
# ---
# Q 3+64
# T 67
# ☒ 1
# ---
# Q 44+99
# T 143
# ☒ 111
# ---
# Q 86+98
# T 184
# ☒ 111
# ---
# Q 32+90
# T 122
# ☒ 11
# ---
# Q 1+72
# T 73
# ☒ 1
# ---
# Q 8+43
# T 51
# ☒ 11
# ---
# Q 8+43
# T 51
# ☒ 11
# ---
#
# --------------------------------------------------
# Iteration 16
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.7349 - acc: 0.4119 - val_loss: 1.7177 - val_acc: 0.4000
# Q 9+63
# T 72
# ☒ 11
# ---
# Q 5+66
# T 71
# ☒ 11
# ---
# Q 4+14
# T 18
# ☒ 1
# ---
# Q 7+73
# T 80
# ☒ 1
# ---
# Q 2+56
# T 58
# ☒ 1
# ---
# Q 40+54
# T 94
# ☒ 11
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 3+35
# T 38
# ☒ 1
# ---
# Q 11+61
# T 72
# ☒ 11
# ---
# Q 4+99
# T 103
# ☒ 11
# ---
#
# --------------------------------------------------
# Iteration 17
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.7052 - acc: 0.4126 - val_loss: 1.6984 - val_acc: 0.4000
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 4+59
# T 63
# ☒ 11
# ---
# Q 48+73
# T 121
# ☒ 110
# ---
# Q 3+3
# T 6
# ☒ 1
# ---
# Q 1+24
# T 25
# ☒ 1
# ---
# Q 5+25
# T 30
# ☒ 15
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 86+98
# T 184
# ☒ 111
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 3+4
# T 7
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 18
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.6821 - acc: 0.4156 - val_loss: 1.6779 - val_acc: 0.3933
# Q 13+73
# T 86
# ☒ 17
# ---
# Q 9+71
# T 80
# ☒ 14
# ---
# Q 3+77
# T 80
# ☒ 12
# ---
# Q 6+99
# T 105
# ☒ 110
# ---
# Q 9+71
# T 80
# ☒ 14
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 8+73
# T 81
# ☒ 12
# ---
# Q 4+14
# T 18
# ☒ 14
# ---
# Q 38+71
# T 109
# ☒ 110
# ---
# Q 86+98
# T 184
# ☒ 111
# ---
#
# --------------------------------------------------
# Iteration 19
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.6628 - acc: 0.4148 - val_loss: 1.6559 - val_acc: 0.3867
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 44+99
# T 143
# ☒ 111
# ---
# Q 2+56
# T 58
# ☒ 13
# ---
# Q 7+35
# T 42
# ☒ 13
# ---
# Q 2+56
# T 58
# ☒ 13
# ---
# Q 7+35
# T 42
# ☒ 13
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 7+59
# T 66
# ☒ 11
# ---
# Q 87+97
# T 184
# ☒ 111
# ---
# Q 1+38
# T 39
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 20
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.6452 - acc: 0.4096 - val_loss: 1.6587 - val_acc: 0.4000
# Q 5+80
# T 85
# ☒ 11
# ---
# Q 3+25
# T 28
# ☒ 13
# ---
# Q 7+59
# T 66
# ☒ 11
# ---
# Q 0+43
# T 43
# ☒ 13
# ---
# Q 9+63
# T 72
# ☒ 13
# ---
# Q 7+73
# T 80
# ☒ 13
# ---
# Q 5+80
# T 85
# ☒ 11
# ---
# Q 5+76
# T 81
# ☒ 11
# ---
# Q 1+38
# T 39
# ☒ 13
# ---
# Q 48+73
# T 121
# ☒ 110
# ---
#
# --------------------------------------------------
# Iteration 21
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.6298 - acc: 0.4126 - val_loss: 1.6314 - val_acc: 0.3867
# Q 11+61
# T 72
# ☒ 17
# ---
# Q 36+54
# T 90
# ☒ 11
# ---
# Q 3+4
# T 7
# ☒ 1
# ---
# Q 13+73
# T 86
# ☒ 17
# ---
# Q 5+66
# T 71
# ☒ 10
# ---
# Q 8+85
# T 93
# ☒ 11
# ---
# Q 0+76
# T 76
# ☒ 14
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 3+35
# T 38
# ☒ 13
# ---
# Q 87+97
# T 184
# ☒ 111
# ---
#
# --------------------------------------------------
# Iteration 22
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.6082 - acc: 0.4156 - val_loss: 1.6286 - val_acc: 0.3867
# Q 40+54
# T 94
# ☒ 115
# ---
# Q 0+43
# T 43
# ☒ 14
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
# Q 1+24
# T 25
# ☒ 1
# ---
# Q 3+4
# T 7
# ☒ 1
# ---
# Q 6+99
# T 105
# ☒ 115
# ---
# Q 3+3
# T 6
# ☒ 1
# ---
# Q 22+44
# T 66
# ☒ 14
# ---
# Q 3+64
# T 67
# ☒ 14
# ---
# Q 8+73
# T 81
# ☒ 14
# ---
#
# --------------------------------------------------
# Iteration 23
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.6001 - acc: 0.4259 - val_loss: 1.6263 - val_acc: 0.4000
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 6+99
# T 105
# ☒ 111
# ---
# Q 0+43
# T 43
# ☒ 14
# ---
# Q 7+73
# T 80
# ☒ 14
# ---
# Q 9+71
# T 80
# ☒ 10
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 8+43
# T 51
# ☒ 14
# ---
# Q 7+73
# T 80
# ☒ 14
# ---
# Q 9+66
# T 75
# ☒ 10
# ---
# Q 3+25
# T 28
# ☒ 10
# ---
#
# --------------------------------------------------
# Iteration 24
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5927 - acc: 0.4333 - val_loss: 1.5941 - val_acc: 0.4200
# Q 14+16
# T 30
# ☒ 14
# ---
# Q 9+66
# T 75
# ☒ 10
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 32+90
# T 122
# ☒ 11
# ---
# Q 1+72
# T 73
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 25
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5804 - acc: 0.4319 - val_loss: 1.5923 - val_acc: 0.4000
# Q 68+82
# T 150
# ☒ 105
# ---
# Q 9+71
# T 80
# ☒ 14
# ---
# Q 3+25
# T 28
# ☒ 13
# ---
# Q 32+90
# T 122
# ☒ 10
# ---
# Q 6+36
# T 42
# ☒ 13
# ---
# Q 36+54
# T 90
# ☒ 10
# ---
# Q 6+36
# T 42
# ☒ 13
# ---
# Q 9+71
# T 80
# ☒ 14
# ---
# Q 14+16
# T 30
# ☒ 14
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 26
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5678 - acc: 0.4437 - val_loss: 1.6258 - val_acc: 0.4000
# Q 14+16
# T 30
# ☒ 14
# ---
# Q 48+73
# T 121
# ☒ 122
# ---
# Q 68+82
# T 150
# ☒ 122
# ---
# Q 87+97
# T 184
# ☒ 112
# ---
# Q 1+72
# T 73
# ☒ 18
# ---
# Q 7+73
# T 80
# ☒ 14
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
# Q 1+24
# T 25
# ☒ 1
# ---
# Q 3+35
# T 38
# ☒ 12
# ---
#
# --------------------------------------------------
# Iteration 27
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5675 - acc: 0.4407 - val_loss: 1.5707 - val_acc: 0.4200
# Q 6+99
# T 105
# ☒ 101
# ---
# Q 5+25
# T 30
# ☒ 10
# ---
# Q 9+63
# T 72
# ☒ 10
# ---
# Q 5+66
# T 71
# ☒ 10
# ---
# Q 3+77
# T 80
# ☒ 10
# ---
# Q 3+13
# T 16
# ☒ 13
# ---
# Q 3+35
# T 38
# ☒ 12
# ---
# Q 3+59
# T 62
# ☒ 10
# ---
# Q 7+35
# T 42
# ☒ 10
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 28
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5558 - acc: 0.4363 - val_loss: 1.5713 - val_acc: 0.4200
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 4+14
# T 18
# ☒ 14
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
# Q 5+25
# T 30
# ☒ 10
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 22+44
# T 66
# ☒ 17
# ---
# Q 5+22
# T 27
# ☒ 13
# ---
#
# --------------------------------------------------
# Iteration 29
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5524 - acc: 0.4407 - val_loss: 1.6188 - val_acc: 0.4200
# Q 86+98
# T 184
# ☒ 115
# ---
# Q 87+97
# T 184
# ☒ 115
# ---
# Q 8+85
# T 93
# ☒ 10
# ---
# Q 44+99
# T 143
# ☒ 115
# ---
# Q 5+66
# T 71
# ☒ 10
# ---
# Q 87+97
# T 184
# ☒ 115
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 36+54
# T 90
# ☒ 10
# ---
# Q 0+43
# T 43
# ☒ 33
# ---
#
# --------------------------------------------------
# Iteration 30
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5475 - acc: 0.4533 - val_loss: 1.5735 - val_acc: 0.4333
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 38+71
# T 109
# ☒ 10
# ---
# Q 3+13
# T 16
# ☒ 33
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 32+90
# T 122
# ☒ 10
# ---
# Q 3+13
# T 16
# ☒ 33
# ---
# Q 3+64
# T 67
# ☒ 17
# ---
# Q 4+14
# T 18
# ☒ 15
# ---
# Q 0+43
# T 43
# ☒ 3
# ---
# Q 2+56
# T 58
# ☒ 17
# ---
#
# --------------------------------------------------
# Iteration 31
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5288 - acc: 0.4526 - val_loss: 1.5703 - val_acc: 0.4267
# Q 8+85
# T 93
# ☒ 10
# ---
# Q 6+99
# T 105
# ☒ 101
# ---
# Q 3+59
# T 62
# ☒ 10
# ---
# Q 2+56
# T 58
# ☒ 17
# ---
# Q 40+54
# T 94
# ☒ 101
# ---
# Q 3+4
# T 7
# ☒ 3
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
# Q 8+43
# T 51
# ☒ 13
# ---
# Q 3+77
# T 80
# ☒ 10
# ---
# Q 2+56
# T 58
# ☒ 17
# ---
#
# --------------------------------------------------
# Iteration 32
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5145 - acc: 0.4563 - val_loss: 1.5490 - val_acc: 0.4200
# Q 5+22
# T 27
# ☒ 33
# ---
# Q 44+99
# T 143
# ☒ 111
# ---
# Q 0+76
# T 76
# ☒ 10
# ---
# Q 36+54
# T 90
# ☒ 10
# ---
# Q 22+44
# T 66
# ☒ 17
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 7+59
# T 66
# ☒ 10
# ---
# Q 8+73
# T 81
# ☒ 12
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 8+85
# T 93
# ☒ 10
# ---
#
# --------------------------------------------------
# Iteration 33
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.5049 - acc: 0.4644 - val_loss: 1.5533 - val_acc: 0.4200
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 32+90
# T 122
# ☒ 10
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 1+72
# T 73
# ☒ 34
# ---
# Q 5+5
# T 10
# ☒ 1
# ---
# Q 0+9
# T 9
# ☒ 11
# ---
# Q 9+66
# T 75
# ☒ 10
# ---
# Q 87+97
# T 184
# ☒ 112
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
#
# --------------------------------------------------
# Iteration 34
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4934 - acc: 0.4556 - val_loss: 1.5533 - val_acc: 0.4200
# Q 8+85
# T 93
# ☒ 10
# ---
# Q 8+43
# T 51
# ☒ 34
# ---
# Q 3+64
# T 67
# ☒ 44
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 8+85
# T 93
# ☒ 10
# ---
# Q 38+71
# T 109
# ☒ 10
# ---
# Q 68+82
# T 150
# ☒ 143
# ---
# Q 5+22
# T 27
# ☒ 33
# ---
# Q 3+35
# T 38
# ☒ 35
# ---
# Q 87+97
# T 184
# ☒ 102
# ---
#
# --------------------------------------------------
# Iteration 35
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4864 - acc: 0.4593 - val_loss: 1.5520 - val_acc: 0.4067
# Q 7+73
# T 80
# ☒ 34
# ---
# Q 7+73
# T 80
# ☒ 34
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 6+36
# T 42
# ☒ 34
# ---
# Q 32+62
# T 94
# ☒ 33
# ---
# Q 48+73
# T 121
# ☒ 133
# ---
# Q 48+73
# T 121
# ☒ 133
# ---
# Q 0+9
# T 9
# ☒ 11
# ---
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 0+43
# T 43
# ☒ 34
# ---
#
# --------------------------------------------------
# Iteration 36
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4773 - acc: 0.4630 - val_loss: 1.5452 - val_acc: 0.4267
# Q 3+25
# T 28
# ☒ 32
# ---
# Q 2+56
# T 58
# ☒ 17
# ---
# Q 3+64
# T 67
# ☒ 37
# ---
# Q 3+77
# T 80
# ☒ 10
# ---
# Q 0+76
# T 76
# ☒ 10
# ---
# Q 5+25
# T 30
# ☒ 10
# ---
# Q 3+35
# T 38
# ☒ 32
# ---
# Q 3+4
# T 7
# ☒ 3
# ---
# Q 3+35
# T 38
# ☒ 32
# ---
# Q 48+73
# T 121
# ☒ 133
# ---
#
# --------------------------------------------------
# Iteration 37
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4667 - acc: 0.4726 - val_loss: 1.5470 - val_acc: 0.4133
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 6+99
# T 105
# ☒ 101
# ---
# Q 3+4
# T 7
# ☒ 3
# ---
# Q 9+71
# T 80
# ☒ 10
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 13+73
# T 86
# ☒ 33
# ---
# Q 6+36
# T 42
# ☒ 33
# ---
# Q 6+99
# T 105
# ☒ 101
# ---
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
#
# --------------------------------------------------
# Iteration 38
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4559 - acc: 0.4704 - val_loss: 1.5452 - val_acc: 0.4267
# Q 13+73
# T 86
# ☒ 33
# ---
# Q 8+85
# T 93
# ☒ 10
# ---
# Q 36+54
# T 90
# ☒ 10
# ---
# Q 7+73
# T 80
# ☒ 34
# ---
# Q 9+63
# T 72
# ☒ 33
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 1+72
# T 73
# ☒ 3
# ---
# Q 22+44
# T 66
# ☒ 37
# ---
# Q 5+22
# T 27
# ☒ 33
# ---
# Q 40+54
# T 94
# ☒ 14
# ---
#
# --------------------------------------------------
# Iteration 39
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4534 - acc: 0.4711 - val_loss: 1.5650 - val_acc: 0.4200
# Q 7+35
# T 42
# ☒ 34
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 32+90
# T 122
# ☒ 10
# ---
# Q 2+56
# T 58
# ☒ 17
# ---
# Q 14+16
# T 30
# ☒ 14
# ---
# Q 3+59
# T 62
# ☒ 10
# ---
# Q 13+73
# T 86
# ☒ 33
# ---
# Q 6+99
# T 105
# ☒ 101
# ---
# Q 40+54
# T 94
# ☒ 145
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
#
# --------------------------------------------------
# Iteration 40
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4458 - acc: 0.4807 - val_loss: 1.5306 - val_acc: 0.4267
# Q 2+56
# T 58
# ☒ 17
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 38+71
# T 109
# ☒ 12
# ---
# Q 9+71
# T 80
# ☒ 10
# ---
# Q 3+4
# T 7
# ☒ 4
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 0+76
# T 76
# ☒ 70
# ---
# Q 9+66
# T 75
# ☒ 10
# ---
# Q 7+59
# T 66
# ☒ 10
# ---
# Q 0+76
# T 76
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 41
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4244 - acc: 0.4881 - val_loss: 1.5371 - val_acc: 0.4267
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 0+9
# T 9
# ☒ 11
# ---
# Q 4+14
# T 18
# ☒ 44
# ---
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 36+54
# T 90
# ☒ 10
# ---
# Q 7+73
# T 80
# ☒ 44
# ---
# Q 86+98
# T 184
# ☒ 157
# ---
# Q 14+16
# T 30
# ☒ 14
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 8+43
# T 51
# ☒ 34
# ---
#
# --------------------------------------------------
# Iteration 42
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4166 - acc: 0.4859 - val_loss: 1.5061 - val_acc: 0.4400
# Q 38+71
# T 109
# ☒ 107
# ---
# Q 3+13
# T 16
# ☒ 33
# ---
# Q 0+43
# T 43
# ☒ 34
# ---
# Q 6+36
# T 42
# ☒ 33
# ---
# Q 44+99
# T 143
# ☒ 111
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 14+16
# T 30
# ☒ 10
# ---
# Q 0+43
# T 43
# ☒ 34
# ---
# Q 0+76
# T 76
# ☒ 70
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
#
# --------------------------------------------------
# Iteration 43
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.4060 - acc: 0.4970 - val_loss: 1.5054 - val_acc: 0.4267
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 7+73
# T 80
# ☒ 44
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 48+73
# T 121
# ☒ 137
# ---
# Q 4+14
# T 18
# ☒ 51
# ---
# Q 3+64
# T 67
# ☒ 47
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
#
# --------------------------------------------------
# Iteration 44
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3917 - acc: 0.5030 - val_loss: 1.5210 - val_acc: 0.4200
# Q 3+64
# T 67
# ☒ 47
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 5+66
# T 71
# ☒ 10
# ---
# Q 3+25
# T 28
# ☒ 32
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 1+38
# T 39
# ☒ 35
# ---
# Q 11+61
# T 72
# ☒ 14
# ---
#
# --------------------------------------------------
# Iteration 45
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3776 - acc: 0.5081 - val_loss: 1.4998 - val_acc: 0.4267
# Q 5+66
# T 71
# ☒ 10
# ---
# Q 14+16
# T 30
# ☒ 14
# ---
# Q 7+73
# T 80
# ☒ 44
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 9+63
# T 72
# ☒ 30
# ---
# Q 5+66
# T 71
# ☒ 10
# ---
# Q 7+73
# T 80
# ☒ 44
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
#
# --------------------------------------------------
# Iteration 46
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3669 - acc: 0.5104 - val_loss: 1.4772 - val_acc: 0.4467
# Q 9+63
# T 72
# ☒ 30
# ---
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 8+43
# T 51
# ☒ 33
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 9+71
# T 80
# ☒ 10
# ---
# Q 4+14
# T 18
# ☒ 41
# ---
# Q 7+91
# T 98
# ☒ 10
# ---
#
# --------------------------------------------------
# Iteration 47
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3505 - acc: 0.5215 - val_loss: 1.4910 - val_acc: 0.4133
# Q 5+25
# T 30
# ☒ 35
# ---
# Q 1+72
# T 73
# ☒ 38
# ---
# Q 0+9
# T 9
# ☒ 11
# ---
# Q 3+13
# T 16
# ☒ 32
# ---
# Q 32+90
# T 122
# ☒ 12
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 3+35
# T 38
# ☒ 35
# ---
# Q 87+97
# T 184
# ☒ 187
# ---
#
# --------------------------------------------------
# Iteration 48
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3386 - acc: 0.5237 - val_loss: 1.4895 - val_acc: 0.4200
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 3+25
# T 28
# ☒ 35
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 6+36
# T 42
# ☒ 34
# ---
# Q 9+63
# T 72
# ☒ 33
# ---
# Q 5+25
# T 30
# ☒ 35
# ---
# Q 3+35
# T 38
# ☒ 35
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 32+62
# T 94
# ☒ 38
# ---
# Q 7+59
# T 66
# ☒ 10
# ---
#
# --------------------------------------------------
# Iteration 49
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3284 - acc: 0.5289 - val_loss: 1.5070 - val_acc: 0.4600
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 7+91
# T 98
# ☒ 103
# ---
# Q 11+61
# T 72
# ☒ 10
# ---
# Q 5+25
# T 30
# ☑ 30
# ---
#
# --------------------------------------------------
# Iteration 50
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3174 - acc: 0.5319 - val_loss: 1.4818 - val_acc: 0.4400
# Q 7+59
# T 66
# ☒ 10
# ---
# Q 1+72
# T 73
# ☒ 38
# ---
# Q 9+71
# T 80
# ☒ 11
# ---
# Q 7+73
# T 80
# ☒ 44
# ---
# Q 1+38
# T 39
# ☒ 3
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 5+5
# T 10
# ☒ 5
# ---
# Q 7+91
# T 98
# ☒ 14
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 44+99
# T 143
# ☒ 151
# ---
#
# --------------------------------------------------
# Iteration 51
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.3058 - acc: 0.5378 - val_loss: 1.4712 - val_acc: 0.4533
# Q 8+73
# T 81
# ☒ 88
# ---
# Q 5+66
# T 71
# ☒ 10
# ---
# Q 0+76
# T 76
# ☒ 88
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 3+25
# T 28
# ☒ 32
# ---
# Q 48+73
# T 121
# ☒ 137
# ---
# Q 3+13
# T 16
# ☒ 32
# ---
# Q 32+90
# T 122
# ☒ 12
# ---
# Q 3+35
# T 38
# ☒ 35
# ---
# Q 48+73
# T 121
# ☒ 137
# ---
#
# --------------------------------------------------
# Iteration 52
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.2824 - acc: 0.5415 - val_loss: 1.4648 - val_acc: 0.4600
# Q 9+63
# T 72
# ☒ 70
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 13+73
# T 86
# ☒ 48
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 48+73
# T 121
# ☒ 137
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 38+71
# T 109
# ☒ 127
# ---
# Q 4+14
# T 18
# ☒ 51
# ---
# Q 5+22
# T 27
# ☒ 32
# ---
#
# --------------------------------------------------
# Iteration 53
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.2703 - acc: 0.5467 - val_loss: 1.4467 - val_acc: 0.4733
# Q 7+35
# T 42
# ☒ 45
# ---
# Q 7+59
# T 66
# ☒ 10
# ---
# Q 44+99
# T 143
# ☒ 151
# ---
# Q 38+71
# T 109
# ☒ 127
# ---
# Q 9+66
# T 75
# ☒ 70
# ---
# Q 5+80
# T 85
# ☒ 10
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 6+99
# T 105
# ☒ 103
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 4+14
# T 18
# ☒ 51
# ---
#
# --------------------------------------------------
# Iteration 54
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.2529 - acc: 0.5467 - val_loss: 1.4627 - val_acc: 0.4667
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 0+76
# T 76
# ☒ 78
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 6+99
# T 105
# ☒ 103
# ---
# Q 8+85
# T 93
# ☒ 90
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 55
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.2391 - acc: 0.5600 - val_loss: 1.4443 - val_acc: 0.4733
# Q 6+99
# T 105
# ☒ 103
# ---
# Q 3+13
# T 16
# ☒ 32
# ---
# Q 7+73
# T 80
# ☒ 44
# ---
# Q 4+59
# T 63
# ☒ 11
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 7+91
# T 98
# ☒ 14
# ---
# Q 8+43
# T 51
# ☒ 45
# ---
# Q 7+59
# T 66
# ☒ 14
# ---
#
# --------------------------------------------------
# Iteration 56
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.2242 - acc: 0.5689 - val_loss: 1.4413 - val_acc: 0.4600
# Q 3+59
# T 62
# ☒ 11
# ---
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 5+22
# T 27
# ☒ 32
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 7+35
# T 42
# ☒ 44
# ---
# Q 1+24
# T 25
# ☒ 3
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 7+35
# T 42
# ☒ 44
# ---
#
# --------------------------------------------------
# Iteration 57
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.2087 - acc: 0.5785 - val_loss: 1.4399 - val_acc: 0.4800
# Q 40+54
# T 94
# ☒ 105
# ---
# Q 4+59
# T 63
# ☒ 10
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 5+76
# T 81
# ☒ 10
# ---
# Q 6+36
# T 42
# ☒ 43
# ---
# Q 5+80
# T 85
# ☒ 10
# ---
#
# --------------------------------------------------
# Iteration 58
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.1950 - acc: 0.5763 - val_loss: 1.4314 - val_acc: 0.4933
# Q 13+73
# T 86
# ☒ 78
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 8+43
# T 51
# ☒ 43
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 1+72
# T 73
# ☒ 38
# ---
# Q 5+22
# T 27
# ☒ 32
# ---
# Q 6+99
# T 105
# ☒ 103
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 59
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.1790 - acc: 0.5889 - val_loss: 1.4127 - val_acc: 0.4867
# Q 7+35
# T 42
# ☒ 44
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 5+80
# T 85
# ☒ 10
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 0+76
# T 76
# ☒ 78
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 60
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.1628 - acc: 0.5896 - val_loss: 1.4044 - val_acc: 0.4867
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 8+43
# T 51
# ☒ 45
# ---
# Q 86+98
# T 184
# ☒ 157
# ---
# Q 87+97
# T 184
# ☒ 182
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 8+43
# T 51
# ☒ 45
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 0+9
# T 9
# ☒ 11
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
#
# --------------------------------------------------
# Iteration 61
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.1500 - acc: 0.6007 - val_loss: 1.4014 - val_acc: 0.4867
# Q 5+22
# T 27
# ☒ 32
# ---
# Q 32+62
# T 94
# ☒ 28
# ---
# Q 1+72
# T 73
# ☒ 38
# ---
# Q 6+36
# T 42
# ☒ 46
# ---
# Q 8+43
# T 51
# ☒ 45
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 5+76
# T 81
# ☒ 70
# ---
# Q 32+90
# T 122
# ☒ 11
# ---
# Q 44+99
# T 143
# ☒ 151
# ---
# Q 9+71
# T 80
# ☒ 14
# ---
#
# --------------------------------------------------
# Iteration 62
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.1340 - acc: 0.6081 - val_loss: 1.4014 - val_acc: 0.4867
# Q 32+62
# T 94
# ☒ 70
# ---
# Q 32+62
# T 94
# ☒ 70
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 8+85
# T 93
# ☒ 80
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 5+22
# T 27
# ☒ 38
# ---
#
# --------------------------------------------------
# Iteration 63
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.1164 - acc: 0.6207 - val_loss: 1.3780 - val_acc: 0.5067
# Q 7+35
# T 42
# ☒ 40
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 1+24
# T 25
# ☒ 35
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 13+73
# T 86
# ☒ 84
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 4+59
# T 63
# ☒ 11
# ---
#
# --------------------------------------------------
# Iteration 64
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.1036 - acc: 0.6237 - val_loss: 1.3874 - val_acc: 0.5067
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 7+35
# T 42
# ☒ 40
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 87+97
# T 184
# ☒ 187
# ---
# Q 3+13
# T 16
# ☒ 22
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 11+61
# T 72
# ☒ 11
# ---
#
# --------------------------------------------------
# Iteration 65
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.0936 - acc: 0.6222 - val_loss: 1.3866 - val_acc: 0.5000
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 5+76
# T 81
# ☒ 80
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 48+73
# T 121
# ☒ 127
# ---
# Q 9+71
# T 80
# ☒ 94
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 1+72
# T 73
# ☒ 48
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
#
# --------------------------------------------------
# Iteration 66
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.0777 - acc: 0.6370 - val_loss: 1.3787 - val_acc: 0.5000
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 1+24
# T 25
# ☒ 35
# ---
# Q 7+59
# T 66
# ☒ 54
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 44+99
# T 143
# ☒ 131
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
#
# --------------------------------------------------
# Iteration 67
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.0646 - acc: 0.6422 - val_loss: 1.3879 - val_acc: 0.4933
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 9+71
# T 80
# ☒ 24
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 8+85
# T 93
# ☒ 80
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 8+85
# T 93
# ☒ 80
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 1+72
# T 73
# ☒ 38
# ---
#
# --------------------------------------------------
# Iteration 68
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.0521 - acc: 0.6393 - val_loss: 1.3710 - val_acc: 0.5067
# Q 5+22
# T 27
# ☒ 31
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 5+80
# T 85
# ☒ 14
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 44+99
# T 143
# ☒ 171
# ---
# Q 13+73
# T 86
# ☒ 84
# ---
# Q 68+82
# T 150
# ☒ 143
# ---
#
# --------------------------------------------------
# Iteration 69
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.0358 - acc: 0.6407 - val_loss: 1.3999 - val_acc: 0.4933
# Q 7+73
# T 80
# ☒ 74
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 44+99
# T 143
# ☒ 171
# ---
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
#
# --------------------------------------------------
# Iteration 70
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.0346 - acc: 0.6467 - val_loss: 1.3567 - val_acc: 0.5133
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 32+62
# T 94
# ☒ 21
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 7+35
# T 42
# ☒ 30
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 5+22
# T 27
# ☒ 31
# ---
#
# --------------------------------------------------
# Iteration 71
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 1.0150 - acc: 0.6541 - val_loss: 1.3868 - val_acc: 0.4733
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 44+99
# T 143
# ☒ 171
# ---
# Q 5+22
# T 27
# ☒ 31
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 0+43
# T 43
# ☒ 46
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
#
# --------------------------------------------------
# Iteration 72
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9991 - acc: 0.6600 - val_loss: 1.3478 - val_acc: 0.5200
# Q 5+80
# T 85
# ☒ 14
# ---
# Q 3+13
# T 16
# ☒ 22
# ---
# Q 5+80
# T 85
# ☒ 14
# ---
# Q 32+62
# T 94
# ☒ 11
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 0+76
# T 76
# ☒ 78
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
#
# --------------------------------------------------
# Iteration 73
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9831 - acc: 0.6600 - val_loss: 1.3567 - val_acc: 0.5133
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 6+36
# T 42
# ☒ 43
# ---
# Q 5+80
# T 85
# ☒ 14
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 7+73
# T 80
# ☒ 73
# ---
# Q 6+36
# T 42
# ☒ 43
# ---
#
# --------------------------------------------------
# Iteration 74
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9666 - acc: 0.6674 - val_loss: 1.3565 - val_acc: 0.5000
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 5+22
# T 27
# ☒ 31
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 5+22
# T 27
# ☒ 31
# ---
# Q 6+36
# T 42
# ☒ 46
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
#
# --------------------------------------------------
# Iteration 75
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9553 - acc: 0.6741 - val_loss: 1.3467 - val_acc: 0.5067
# Q 32+62
# T 94
# ☒ 11
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 3+13
# T 16
# ☒ 22
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 6+36
# T 42
# ☒ 33
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
#
# --------------------------------------------------
# Iteration 76
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9378 - acc: 0.6844 - val_loss: 1.3371 - val_acc: 0.4867
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 11+61
# T 72
# ☒ 11
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 3+13
# T 16
# ☒ 22
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 9+63
# T 72
# ☒ 73
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
#
# --------------------------------------------------
# Iteration 77
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9256 - acc: 0.6844 - val_loss: 1.3326 - val_acc: 0.5133
# Q 32+62
# T 94
# ☒ 11
# ---
# Q 5+22
# T 27
# ☒ 31
# ---
# Q 44+99
# T 143
# ☒ 171
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 1+72
# T 73
# ☒ 78
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 5+76
# T 81
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 78
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9156 - acc: 0.6852 - val_loss: 1.3465 - val_acc: 0.5000
# Q 6+36
# T 42
# ☒ 33
# ---
# Q 8+85
# T 93
# ☒ 80
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 7+59
# T 66
# ☒ 54
# ---
# Q 7+73
# T 80
# ☒ 73
# ---
# Q 48+73
# T 121
# ☒ 113
# ---
#
# --------------------------------------------------
# Iteration 79
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.9024 - acc: 0.6956 - val_loss: 1.3314 - val_acc: 0.5067
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
# Q 7+73
# T 80
# ☒ 73
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 5+80
# T 85
# ☒ 15
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 9+71
# T 80
# ☒ 24
# ---
# Q 2+56
# T 58
# ☒ 77
# ---
#
# --------------------------------------------------
# Iteration 80
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.8939 - acc: 0.7030 - val_loss: 1.3369 - val_acc: 0.5133
# Q 0+9
# T 9
# ☒ 10
# ---
# Q 5+80
# T 85
# ☒ 14
# ---
# Q 1+72
# T 73
# ☒ 78
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 5+76
# T 81
# ☒ 70
# ---
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 6+36
# T 42
# ☒ 38
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 44+99
# T 143
# ☒ 171
# ---
#
# --------------------------------------------------
# Iteration 81
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.8794 - acc: 0.7015 - val_loss: 1.3323 - val_acc: 0.4867
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 82
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.8657 - acc: 0.7089 - val_loss: 1.3483 - val_acc: 0.5133
# Q 8+43
# T 51
# ☒ 43
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 1+72
# T 73
# ☑ 73
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
#
# --------------------------------------------------
# Iteration 83
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.8519 - acc: 0.7244 - val_loss: 1.3209 - val_acc: 0.5000
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
#
# --------------------------------------------------
# Iteration 84
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.8392 - acc: 0.7252 - val_loss: 1.3243 - val_acc: 0.4800
# Q 6+36
# T 42
# ☒ 36
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 3+13
# T 16
# ☒ 20
# ---
# Q 5+22
# T 27
# ☒ 30
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
#
# --------------------------------------------------
# Iteration 85
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.8264 - acc: 0.7281 - val_loss: 1.3199 - val_acc: 0.5200
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 6+36
# T 42
# ☒ 38
# ---
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 7+35
# T 42
# ☒ 40
# ---
#
# --------------------------------------------------
# Iteration 86
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.8145 - acc: 0.7267 - val_loss: 1.3116 - val_acc: 0.5267
# Q 44+99
# T 143
# ☒ 171
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 8+85
# T 93
# ☒ 80
# ---
# Q 32+62
# T 94
# ☒ 12
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 5+25
# T 30
# ☑ 30
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 1+72
# T 73
# ☑ 73
# ---
#
# --------------------------------------------------
# Iteration 87
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7998 - acc: 0.7304 - val_loss: 1.3199 - val_acc: 0.5133
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 3+35
# T 38
# ☒ 36
# ---
# Q 40+54
# T 94
# ☒ 10
# ---
# Q 5+22
# T 27
# ☒ 21
# ---
# Q 9+71
# T 80
# ☒ 74
# ---
# Q 5+76
# T 81
# ☒ 70
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 5+80
# T 85
# ☒ 15
# ---
# Q 8+85
# T 93
# ☒ 80
# ---
#
# --------------------------------------------------
# Iteration 88
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7844 - acc: 0.7467 - val_loss: 1.3167 - val_acc: 0.5067
# Q 5+76
# T 81
# ☒ 70
# ---
# Q 7+73
# T 80
# ☒ 73
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 11+61
# T 72
# ☒ 71
# ---
# Q 1+72
# T 73
# ☒ 78
# ---
# Q 1+72
# T 73
# ☒ 78
# ---
# Q 86+98
# T 184
# ☒ 177
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
#
# --------------------------------------------------
# Iteration 89
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7740 - acc: 0.7474 - val_loss: 1.3049 - val_acc: 0.5000
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 5+80
# T 85
# ☒ 15
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 5+22
# T 27
# ☒ 20
# ---
# Q 0+76
# T 76
# ☒ 78
# ---
# Q 8+43
# T 51
# ☒ 48
# ---
# Q 3+35
# T 38
# ☒ 36
# ---
# Q 48+73
# T 121
# ☒ 110
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
#
# --------------------------------------------------
# Iteration 90
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7615 - acc: 0.7622 - val_loss: 1.3099 - val_acc: 0.5000
# Q 3+13
# T 16
# ☒ 20
# ---
# Q 5+76
# T 81
# ☒ 70
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 11+61
# T 72
# ☒ 71
# ---
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 11+61
# T 72
# ☒ 71
# ---
# Q 5+80
# T 85
# ☒ 15
# ---
#
# --------------------------------------------------
# Iteration 91
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7516 - acc: 0.7600 - val_loss: 1.3176 - val_acc: 0.5133
# Q 4+14
# T 18
# ☒ 17
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 44+99
# T 143
# ☒ 171
# ---
# Q 40+54
# T 94
# ☒ 84
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 48+73
# T 121
# ☒ 117
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 11+61
# T 72
# ☒ 71
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 92
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7396 - acc: 0.7585 - val_loss: 1.3205 - val_acc: 0.4867
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 3+13
# T 16
# ☒ 10
# ---
# Q 3+35
# T 38
# ☒ 36
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 9+71
# T 80
# ☒ 74
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 6+36
# T 42
# ☒ 38
# ---
#
# --------------------------------------------------
# Iteration 93
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7280 - acc: 0.7644 - val_loss: 1.3169 - val_acc: 0.5333
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 5+25
# T 30
# ☒ 20
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
# Q 7+59
# T 66
# ☒ 55
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
#
# --------------------------------------------------
# Iteration 94
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7185 - acc: 0.7800 - val_loss: 1.3267 - val_acc: 0.5000
# Q 9+71
# T 80
# ☒ 74
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 7+35
# T 42
# ☒ 40
# ---
# Q 9+71
# T 80
# ☒ 74
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 11+61
# T 72
# ☒ 71
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 7+91
# T 98
# ☒ 16
# ---
#
# --------------------------------------------------
# Iteration 95
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.7053 - acc: 0.7785 - val_loss: 1.3067 - val_acc: 0.5067
# Q 36+54
# T 90
# ☒ 70
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 5+22
# T 27
# ☒ 20
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 5+80
# T 85
# ☒ 15
# ---
# Q 5+22
# T 27
# ☒ 20
# ---
# Q 8+43
# T 51
# ☒ 49
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
#
# --------------------------------------------------
# Iteration 96
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.6934 - acc: 0.7926 - val_loss: 1.3039 - val_acc: 0.5067
# Q 5+76
# T 81
# ☒ 70
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 8+85
# T 93
# ☒ 84
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 5+22
# T 27
# ☒ 20
# ---
#
# --------------------------------------------------
# Iteration 97
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.6893 - acc: 0.7911 - val_loss: 1.3376 - val_acc: 0.4933
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 8+73
# T 81
# ☒ 83
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 7+35
# T 42
# ☒ 40
# ---
# Q 3+64
# T 67
# ☒ 71
# ---
# Q 3+3
# T 6
# ☒ 3
# ---
# Q 3+59
# T 62
# ☒ 51
# ---
#
# --------------------------------------------------
# Iteration 98
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.6817 - acc: 0.7926 - val_loss: 1.3167 - val_acc: 0.5133
# Q 7+59
# T 66
# ☒ 50
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 44+99
# T 143
# ☒ 131
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 0+43
# T 43
# ☒ 46
# ---
# Q 0+43
# T 43
# ☒ 46
# ---
#
# --------------------------------------------------
# Iteration 99
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.6691 - acc: 0.7985 - val_loss: 1.3402 - val_acc: 0.4867
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 9+71
# T 80
# ☒ 75
# ---
# Q 48+73
# T 121
# ☒ 110
# ---
# Q 32+62
# T 94
# ☒ 12
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 11+61
# T 72
# ☒ 71
# ---
# Q 9+66
# T 75
# ☒ 77
# ---
# Q 9+66
# T 75
# ☒ 77
# ---
#
# --------------------------------------------------
# Iteration 100
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.6619 - acc: 0.8096 - val_loss: 1.3107 - val_acc: 0.5133
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 7+73
# T 80
# ☒ 73
# ---
# Q 40+54
# T 94
# ☒ 84
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 6+36
# T 42
# ☒ 33
# ---
# Q 11+61
# T 72
# ☒ 71
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
#
# --------------------------------------------------
# Iteration 101
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.6446 - acc: 0.8126 - val_loss: 1.3158 - val_acc: 0.5000
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 32+62
# T 94
# ☒ 72
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 7+35
# T 42
# ☒ 40
# ---
# Q 7+35
# T 42
# ☒ 40
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 0+43
# T 43
# ☒ 46
# ---
# Q 22+44
# T 66
# ☒ 77
# ---
# Q 8+43
# T 51
# ☒ 49
# ---
# Q 5+76
# T 81
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 102
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.6349 - acc: 0.8185 - val_loss: 1.2960 - val_acc: 0.5333
# Q 8+43
# T 51
# ☒ 49
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 3+35
# T 38
# ☒ 36
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# ...
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1986 - acc: 0.9800 - val_loss: 1.3526 - val_acc: 0.6000
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 48+73
# T 121
# ☒ 112
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 5+80
# T 85
# ☑ 85
# ---
# Q 4+59
# T 63
# ☒ 51
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 7+73
# T 80
# ☒ 79
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 167
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1946 - acc: 0.9793 - val_loss: 1.3729 - val_acc: 0.5867
# Q 11+61
# T 72
# ☒ 74
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 8+73
# T 81
# ☒ 82
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 7+59
# T 66
# ☑ 66
# ---
#
# --------------------------------------------------
# Iteration 168
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1918 - acc: 0.9800 - val_loss: 1.3568 - val_acc: 0.5800
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 36+54
# T 90
# ☒ 81
# ---
# Q 11+61
# T 72
# ☑ 72
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 11+61
# T 72
# ☑ 72
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 5+80
# T 85
# ☑ 85
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 32+90
# T 122
# ☒ 121
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
#
# --------------------------------------------------
# Iteration 169
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1886 - acc: 0.9778 - val_loss: 1.3763 - val_acc: 0.5733
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 7+35
# T 42
# ☒ 43
# ---
# Q 22+44
# T 66
# ☒ 76
# ---
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 5+76
# T 81
# ☒ 80
# ---
# Q 44+99
# T 143
# ☒ 135
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
#
# --------------------------------------------------
# Iteration 170
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1861 - acc: 0.9822 - val_loss: 1.3788 - val_acc: 0.6000
# Q 7+73
# T 80
# ☒ 79
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 68+82
# T 150
# ☒ 138
# ---
# Q 7+35
# T 42
# ☒ 43
# ---
# Q 6+99
# T 105
# ☒ 107
# ---
# Q 36+54
# T 90
# ☒ 89
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 32+90
# T 122
# ☒ 121
# ---
#
# --------------------------------------------------
# Iteration 171
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1832 - acc: 0.9800 - val_loss: 1.3622 - val_acc: 0.5933
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 8+43
# T 51
# ☒ 52
# ---
# Q 6+36
# T 42
# ☒ 43
# ---
# Q 32+62
# T 94
# ☒ 76
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 44+99
# T 143
# ☒ 133
# ---
# Q 38+71
# T 109
# ☒ 102
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
#
# --------------------------------------------------
# Iteration 172
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1805 - acc: 0.9815 - val_loss: 1.3710 - val_acc: 0.5867
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 7+59
# T 66
# ☒ 65
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 3+3
# T 6
# ☒ 4
# ---
# Q 48+73
# T 121
# ☒ 112
# ---
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 38+71
# T 109
# ☒ 102
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 7+59
# T 66
# ☒ 65
# ---
#
# --------------------------------------------------
# Iteration 173
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1769 - acc: 0.9800 - val_loss: 1.3833 - val_acc: 0.6133
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 6+99
# T 105
# ☒ 107
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 40+54
# T 94
# ☒ 84
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 8+73
# T 81
# ☒ 82
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 38+71
# T 109
# ☒ 102
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
#
# --------------------------------------------------
# Iteration 174
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1738 - acc: 0.9822 - val_loss: 1.3678 - val_acc: 0.5933
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 5+76
# T 81
# ☒ 80
# ---
# Q 22+44
# T 66
# ☒ 76
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
# Q 32+62
# T 94
# ☒ 72
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 11+61
# T 72
# ☑ 72
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
#
# --------------------------------------------------
# Iteration 175
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1706 - acc: 0.9822 - val_loss: 1.3760 - val_acc: 0.6000
# Q 7+91
# T 98
# ☒ 96
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 11+61
# T 72
# ☑ 72
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 3+59
# T 62
# ☒ 60
# ---
# Q 44+99
# T 143
# ☒ 133
# ---
# Q 7+73
# T 80
# ☒ 79
# ---
#
# --------------------------------------------------
# Iteration 176
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1681 - acc: 0.9859 - val_loss: 1.4112 - val_acc: 0.5867
# Q 7+35
# T 42
# ☒ 43
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 3+25
# T 28
# ☒ 36
# ---
# Q 8+43
# T 51
# ☒ 52
# ---
# Q 32+62
# T 94
# ☒ 72
# ---
# Q 6+36
# T 42
# ☒ 43
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
#
# --------------------------------------------------
# Iteration 177
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1649 - acc: 0.9844 - val_loss: 1.3829 - val_acc: 0.6067
# Q 40+54
# T 94
# ☒ 84
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 7+73
# T 80
# ☒ 79
# ---
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 9+71
# T 80
# ☒ 79
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 7+73
# T 80
# ☒ 79
# ---
# Q 3+35
# T 38
# ☒ 36
# ---
#
# --------------------------------------------------
# Iteration 178
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1621 - acc: 0.9830 - val_loss: 1.3841 - val_acc: 0.6000
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
# Q 7+91
# T 98
# ☒ 96
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 179
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1595 - acc: 0.9874 - val_loss: 1.3941 - val_acc: 0.6000
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 32+90
# T 122
# ☒ 121
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 9+71
# T 80
# ☒ 79
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 32+62
# T 94
# ☒ 72
# ---
#
# --------------------------------------------------
# Iteration 180
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1579 - acc: 0.9859 - val_loss: 1.4034 - val_acc: 0.5933
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 3+59
# T 62
# ☒ 60
# ---
# Q 9+71
# T 80
# ☒ 79
# ---
# Q 5+76
# T 81
# ☒ 80
# ---
# Q 8+43
# T 51
# ☒ 52
# ---
# Q 3+59
# T 62
# ☒ 60
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 11+61
# T 72
# ☑ 72
# ---
#
# --------------------------------------------------
# Iteration 181
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1539 - acc: 0.9859 - val_loss: 1.3987 - val_acc: 0.5933
# Q 8+43
# T 51
# ☒ 52
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 9+66
# T 75
# ☑ 75
# ---
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 5+80
# T 85
# ☑ 85
# ---
# Q 3+59
# T 62
# ☒ 60
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
#
# --------------------------------------------------
# Iteration 182
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1524 - acc: 0.9881 - val_loss: 1.4038 - val_acc: 0.5933
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 3+59
# T 62
# ☒ 60
# ---
# Q 7+35
# T 42
# ☒ 43
# ---
# Q 3+25
# T 28
# ☒ 36
# ---
# Q 3+25
# T 28
# ☒ 36
# ---
# Q 8+73
# T 81
# ☒ 82
# ---
# Q 44+99
# T 143
# ☒ 133
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 44+99
# T 143
# ☒ 133
# ---
#
# --------------------------------------------------
# Iteration 183
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1500 - acc: 0.9874 - val_loss: 1.4196 - val_acc: 0.5933
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 4+59
# T 63
# ☒ 61
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 44+99
# T 143
# ☒ 133
# ---
# Q 7+59
# T 66
# ☒ 65
# ---
# Q 5+76
# T 81
# ☒ 80
# ---
# Q 48+73
# T 121
# ☒ 112
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
#
# --------------------------------------------------
# Iteration 184
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1476 - acc: 0.9859 - val_loss: 1.4060 - val_acc: 0.5933
# Q 40+54
# T 94
# ☒ 84
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 40+54
# T 94
# ☒ 84
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 9+71
# T 80
# ☒ 79
# ---
# Q 48+73
# T 121
# ☒ 112
# ---
#
# --------------------------------------------------
# Iteration 185
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1452 - acc: 0.9926 - val_loss: 1.4208 - val_acc: 0.6000
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 32+62
# T 94
# ☒ 72
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 11+61
# T 72
# ☑ 72
# ---
# Q 22+44
# T 66
# ☒ 76
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
#
# --------------------------------------------------
# Iteration 186
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1424 - acc: 0.9889 - val_loss: 1.4089 - val_acc: 0.6000
# Q 48+73
# T 121
# ☒ 112
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 4+14
# T 18
# ☒ 11
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
#
# --------------------------------------------------
# Iteration 187
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1392 - acc: 0.9904 - val_loss: 1.4226 - val_acc: 0.6067
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 8+43
# T 51
# ☒ 52
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 0+43
# T 43
# ☒ 44
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 7+73
# T 80
# ☒ 79
# ---
# Q 7+59
# T 66
# ☑ 66
# ---
# Q 32+62
# T 94
# ☒ 72
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
#
# --------------------------------------------------
# Iteration 188
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1371 - acc: 0.9911 - val_loss: 1.4174 - val_acc: 0.6000
# Q 7+73
# T 80
# ☒ 79
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
# Q 6+36
# T 42
# ☒ 43
# ---
# Q 36+54
# T 90
# ☒ 81
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 6+99
# T 105
# ☒ 107
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 48+73
# T 121
# ☒ 112
# ---
# Q 7+91
# T 98
# ☒ 96
# ---
#
# --------------------------------------------------
# Iteration 189
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1353 - acc: 0.9874 - val_loss: 1.4113 - val_acc: 0.6133
# Q 3+3
# T 6
# ☒ 4
# ---
# Q 3+25
# T 28
# ☒ 27
# ---
# Q 38+71
# T 109
# ☒ 102
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 8+43
# T 51
# ☒ 52
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 87+97
# T 184
# ☒ 186
# ---
# Q 32+90
# T 122
# ☒ 121
# ---
#
# --------------------------------------------------
# Iteration 190
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1330 - acc: 0.9911 - val_loss: 1.4237 - val_acc: 0.6000
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 9+71
# T 80
# ☒ 79
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 6+36
# T 42
# ☒ 43
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
#
# --------------------------------------------------
# Iteration 191
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1302 - acc: 0.9919 - val_loss: 1.4276 - val_acc: 0.6000
# Q 8+43
# T 51
# ☒ 52
# ---
# Q 68+82
# T 150
# ☒ 133
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 3+4
# T 7
# ☒ 4
# ---
# Q 3+25
# T 28
# ☒ 37
# ---
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 1+72
# T 73
# ☒ 71
# ---
# Q 8+85
# T 93
# ☒ 94
# ---
# Q 7+59
# T 66
# ☑ 66
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
#
# --------------------------------------------------
# Iteration 192
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1288 - acc: 0.9919 - val_loss: 1.4366 - val_acc: 0.5933
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 38+71
# T 109
# ☒ 102
# ---
# Q 1+38
# T 39
# ☒ 48
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 7+35
# T 42
# ☒ 43
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
#
# --------------------------------------------------
# Iteration 193
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1264 - acc: 0.9896 - val_loss: 1.4342 - val_acc: 0.6067
# Q 14+16
# T 30
# ☒ 11
# ---
# Q 2+56
# T 58
# ☒ 67
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 4+59
# T 63
# ☒ 60
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
#
# --------------------------------------------------
# Iteration 194
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1245 - acc: 0.9919 - val_loss: 1.4276 - val_acc: 0.5867
# Q 5+5
# T 10
# ☒ 11
# ---
# Q 7+59
# T 66
# ☒ 65
# ---
# Q 5+76
# T 81
# ☒ 80
# ---
# Q 38+71
# T 109
# ☒ 122
# ---
# Q 3+4
# T 7
# ☒ 5
# ---
# Q 44+99
# T 143
# ☒ 133
# ---
# Q 2+56
# T 58
# ☒ 57
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 3+59
# T 62
# ☒ 60
# ---
#
# --------------------------------------------------
# Iteration 195
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1237 - acc: 0.9904 - val_loss: 1.4489 - val_acc: 0.5933
# Q 9+66
# T 75
# ☑ 75
# ---
# Q 9+71
# T 80
# ☒ 79
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
# Q 7+59
# T 66
# ☑ 66
# ---
# Q 4+59
# T 63
# ☒ 60
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 5+80
# T 85
# ☑ 85
# ---
# Q 7+91
# T 98
# ☒ 96
# ---
# Q 2+56
# T 58
# ☒ 57
# ---
#
# --------------------------------------------------
# Iteration 196
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1220 - acc: 0.9933 - val_loss: 1.4577 - val_acc: 0.6000
# Q 68+82
# T 150
# ☒ 138
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 32+62
# T 94
# ☒ 71
# ---
# Q 32+62
# T 94
# ☒ 71
# ---
# Q 1+24
# T 25
# ☒ 36
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 2+56
# T 58
# ☒ 57
# ---
# Q 11+61
# T 72
# ☒ 74
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 0+76
# T 76
# ☒ 77
# ---
#
# --------------------------------------------------
# Iteration 197
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1195 - acc: 0.9919 - val_loss: 1.4399 - val_acc: 0.6000
# Q 5+80
# T 85
# ☑ 85
# ---
# Q 9+66
# T 75
# ☑ 75
# ---
# Q 32+90
# T 122
# ☒ 111
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 4+14
# T 18
# ☒ 17
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 4+59
# T 63
# ☒ 60
# ---
# Q 4+99
# T 103
# ☒ 101
# ---
# Q 3+35
# T 38
# ☒ 37
# ---
#
# --------------------------------------------------
# Iteration 198
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1171 - acc: 0.9926 - val_loss: 1.4430 - val_acc: 0.6000
# Q 3+35
# T 38
# ☒ 37
# ---
# Q 7+73
# T 80
# ☒ 79
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
# Q 36+54
# T 90
# ☒ 81
# ---
# Q 5+22
# T 27
# ☒ 35
# ---
# Q 6+99
# T 105
# ☑ 105
# ---
# Q 9+63
# T 72
# ☒ 74
# ---
# Q 44+99
# T 143
# ☒ 133
# ---
# Q 13+73
# T 86
# ☒ 77
# ---
# Q 7+35
# T 42
# ☒ 43
# ---
#
# --------------------------------------------------
# Iteration 199
# Train on 450 samples, validate on 50 samples
# Epoch 1/1
# 450/450 [==============================] - 0s - loss: 0.1153 - acc: 0.9948 - val_loss: 1.4584 - val_acc: 0.5933
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 3+13
# T 16
# ☒ 17
# ---
# Q 86+98
# T 184
# ☒ 155
# ---
# Q 38+71
# T 109
# ☒ 102
# ---
# Q 3+77
# T 80
# ☒ 89
# ---
# Q 0+9
# T 9
# ☒ 1
# ---
# Q 5+25
# T 30
# ☒ 31
# ---
# Q 32+62
# T 94
# ☒ 72
# ---
# Q 5+66
# T 71
# ☒ 70
# ---
# Q 3+64
# T 67
# ☒ 77
# ---
